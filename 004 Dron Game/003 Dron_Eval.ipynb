# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import gymnasium as gym
import nbformat

# %%
class_path= "/content/drive/MyDrive/husob/06 ReinForcement Learning/004/Drone_env.ipynb"
with open(class_path, 'r') as f:
    nb = nbformat.read(f, as_version=4)

# %%
for cell in nb.cells:
    if cell.cell_type == 'code':
       try:
        exec(cell.source, globals())
       except Exception as e:
        print(f"Error executing cell: {e}")
# Out:
# Error executing cell: not enough values to unpack (expected 5, got 4)

# %%
import pickle
def load_q_table_and_env(q_table_path,best_q_table_path, env_path):
    with open(q_table_path, 'rb') as f:
        q_table = pickle.load(f)

    with open(best_q_table_path, 'rb') as f:
        best_q_table = pickle.load(f)
    with open(env_path, 'rb') as f:
        env = pickle.load(f)
    return q_table,best_q_table , env

# %%
working_dir = "/content/drive/MyDrive/husob/06 ReinForcement Learning/004/"
q_table_name = working_dir + "q_table1.pkl"
best_q_table_name = working_dir + "best_q_table1.pkl"
env_name = working_dir + "env1.pkl"
q_table,best_q_table ,env = load_q_table_and_env(q_table_name,best_q_table_name ,env_name)

# %%
import numpy as np
import time
from tqdm import trange
from IPython.display import clear_output

# --- Q-Learning Agent ---
class QLearningAgent:
    """
    A Q-Learning agent for discrete observation and action spaces.
    """
    def __init__(self, observation_space_size, action_space_size, learning_rate=0.1, discount_factor=0.99, epsilon=1.0):
        self.q_table = np.zeros((observation_space_size, action_space_size))
        self.learning_rate = learning_rate  # Alpha
        self.discount_factor = discount_factor  # Gamma
        self.epsilon = epsilon  # Exploration factor

    def choose_action(self, state):
        """
        Chooses an action using an epsilon-greedy policy.
        """
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.q_table.shape[1])  # Explore
        else:
            return np.argmax(self.q_table[state])  # Exploit

    def learn(self, state, action, reward, next_state):
        """
        Q(s,a) = Q(s,a) + alpha * (reward + gamma * max(Q(s',a')) - Q(s,a))
        """
        old_value = self.q_table[state, action]
        next_max = np.max(self.q_table[next_state])
        new_value = old_value + self.learning_rate * (reward + self.discount_factor * next_max - old_value)
        self.q_table[state, action] = new_value

# %%
from IPython.display import clear_output
import time

# --- Evaluation Function ---
def evaluate_agent(env, agent, goal_position, num_episodes=5):
    """
    Runs the agent in exploitation mode (no exploration) and renders episodes.
    """
    original_epsilon = agent.epsilon
    agent.epsilon = 0  # Turn off exploration

    print(f"\nEvaluating agent for {num_episodes} episodes...")

    for episode in range(num_episodes):
        # Reset the environment and get the initial observation (drone's start position)
        state, info = env.reset() # 'info' might contain additional details, good practice to capture

        # Set the goal for the environment
        raw_env = env.unwrapped
        raw_env.set_goal(goal_position) # This sets the target for the environment's internal logic

        # No need to set 'state' to goal_position here.
        # 'state' from env.reset() is the correct starting observation.

        done = False
        total_reward = 0

        print(f"\n--- Episode {episode + 1} ---")
        env.render() # Render initial state

        while not done:
            action = agent.choose_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward
            state = next_state # Update state for the next iteration
            done = terminated or truncated
            if done:
               clear_output(wait=True)
               env.render() # Render after each step to see progression
               time.sleep(0.1)

        print(f"Episode {episode + 1} reward: {total_reward:.2f}")

    # Restore original epsilon after evaluation
    agent.epsilon = original_epsilon

# %%
agent = QLearningAgent(observation_space_size=env.observation_space.n, action_space_size=env.action_space.n)
agent.q_table = q_table
goal_position = [9,0,8]

evaluate_agent(env, agent,goal_position, num_episodes=1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b048fffe-38e2-4522-96fc-8c7f81cb845c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b048fffe-38e2-4522-96fc-8c7f81cb845c")) {                    Plotly.newPlot(                        "b048fffe-38e2-4522-96fc-8c7f81cb845c",                        [{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,8,8,3],"y":[3,3,8,8],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,8,8,3],"y":[3,3,8,8],"z":[5,5,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,8,8,3],"y":[3,3,3,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,3,3,8],"y":[8,8,8,8],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,8,8,8],"y":[3,8,8,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,3,3,3],"y":[3,8,8,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,9,9,8],"y":[8,8,9,9],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,9,9,8],"y":[8,8,9,9],"z":[1,1,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,9,9,8],"y":[8,8,8,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[9,8,8,9],"y":[9,9,9,9],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[9,9,9,9],"y":[8,9,9,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,8,8,8],"y":[8,9,9,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,2,2,0],"y":[2,2,6,6],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,2,2,0],"y":[2,2,6,6],"z":[4,4,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,2,2,0],"y":[2,2,2,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[2,0,0,2],"y":[6,6,6,6],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[2,2,2,2],"y":[2,6,6,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,0,0,0],"y":[2,6,6,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,10,10,8],"y":[1,1,3,3],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,10,10,8],"y":[1,1,3,3],"z":[5,5,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,10,10,8],"y":[1,1,1,1],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[10,8,8,10],"y":[3,3,3,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[10,10,10,10],"y":[1,3,3,1],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,8,8,8],"y":[1,3,3,1],"z":[0,0,5,5],"type":"scatter3d"},{"marker":{"color":"green","size":10},"mode":"markers","name":"Start","showlegend":false,"x":[1],"y":[9],"z":[0],"type":"scatter3d"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"Goal","showlegend":false,"x":[9],"y":[0],"z":[8],"type":"scatter3d"},{"li ...
# Episode 1 reward: 976.00

# %%
agent = QLearningAgent(observation_space_size=env.observation_space.n, action_space_size=env.action_space.n)
agent.q_table = best_q_table
goal_position = [9,8,8]

evaluate_agent(env, agent,goal_position, num_episodes=3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0c5dbc6a-ff99-4af5-af1a-b55f0921bdd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c5dbc6a-ff99-4af5-af1a-b55f0921bdd6")) {                    Plotly.newPlot(                        "0c5dbc6a-ff99-4af5-af1a-b55f0921bdd6",                        [{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,8,8,3],"y":[3,3,8,8],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,8,8,3],"y":[3,3,8,8],"z":[5,5,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,8,8,3],"y":[3,3,3,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,3,3,8],"y":[8,8,8,8],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,8,8,8],"y":[3,8,8,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[3,3,3,3],"y":[3,8,8,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,9,9,8],"y":[8,8,9,9],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,9,9,8],"y":[8,8,9,9],"z":[1,1,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,9,9,8],"y":[8,8,8,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[9,8,8,9],"y":[9,9,9,9],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[9,9,9,9],"y":[8,9,9,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"yellow","width":4},"mode":"lines","showlegend":false,"x":[8,8,8,8],"y":[8,9,9,8],"z":[0,0,1,1],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,2,2,0],"y":[2,2,6,6],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,2,2,0],"y":[2,2,6,6],"z":[4,4,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,2,2,0],"y":[2,2,2,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[2,0,0,2],"y":[6,6,6,6],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[2,2,2,2],"y":[2,6,6,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[0,0,0,0],"y":[2,6,6,2],"z":[0,0,4,4],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,10,10,8],"y":[1,1,3,3],"z":[0,0,0,0],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,10,10,8],"y":[1,1,3,3],"z":[5,5,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,10,10,8],"y":[1,1,1,1],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[10,8,8,10],"y":[3,3,3,3],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[10,10,10,10],"y":[1,3,3,1],"z":[0,0,5,5],"type":"scatter3d"},{"line":{"color":"red","width":4},"mode":"lines","showlegend":false,"x":[8,8,8,8],"y":[1,3,3,1],"z":[0,0,5,5],"type":"scatter3d"},{"marker":{"color":"green","size":10},"mode":"markers","name":"Start","showlegend":false,"x":[1],"y":[9],"z":[0],"type":"scatter3d"},{"marker":{"color":"blue","size":10},"mode":"markers","name":"Goal","showlegend":false,"x":[9],"y":[8],"z":[8],"type":"scatter3d"},{"li ...
# Episode 3 reward: 984.00
