# %%
# !pip install panda-gym
# Out:
# Collecting panda-gym
#   Downloading panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: gymnasium>=0.26 in c:\users\user\anaconda3\envs\ai_env\lib\site-packages (from panda-gym) (1.2.0)
# Collecting pybullet (from panda-gym)
#   Downloading pybullet-3.2.7.tar.gz (80.5 MB)
#      ---------------------------------------- 0.0/80.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/80.5 MB ? eta -:--:--
#       --------------------------------------- 1.3/80.5 MB 5.2 MB/s eta 0:00:16
#      --- ------------------------------------ 6.6/80.5 MB 16.1 MB/s eta 0:00:05
#      ------- ------------------------------- 16.0/80.5 MB 24.0 MB/s eta 0:00:03
#      --------- ----------------------------- 18.6/80.5 MB 24.0 MB/s eta 0:00:03
#      -------------- ------------------------ 30.4/80.5 MB 28.8 MB/s eta 0:00:02
#      ----------------- --------------------- 36.7/80.5 MB 28.4 MB/s eta 0:00:02
#      ------------------- ------------------- 40.9/80.5 MB 27.7 MB/s eta 0:00:02
#      ---------------------- ---------------- 46.7/80.5 MB 27.2 MB/s eta 0:00:02
#      ------------------------- ------------- 52.2/80.5 MB 27.2 MB/s eta 0:00:02
#      ---------------------------- ---------- 59.5/80.5 MB 28.1 MB/s eta 0:00:01
#      -------------------------------- ------ 66.8/80.5 MB 28.6 MB/s eta 0:00:01
#      ------------------------------------ -- 75.0/80.5 MB 29.3 MB/s eta 0:00:01
#      --------------------------------------  80.5/80.5 MB 29.7 MB/s eta 0:00:01
#      --------------------------------------- 80.5/80.5 MB 27.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\ai_env\lib\site-packages (from panda-gym) (2.2.6)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\envs\ai_env\lib\site-packages (from panda-gym) (1.13.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\user\anaconda3\envs\ai_env\lib\site-packages (from gymnasium>=0.26->panda-gym) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\user\anaconda3\envs\ai_env\lib\site-packages (from gymnasium>=0.26->panda-gym) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\user\anaconda3\envs\ai_env\lib\site-packages (from gymnasium>=0.26->panda-gym) (0.0.4)
# Downloading panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py): started
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): still running...
#   Building wheel for pybullet (setup.py): finished with status 'done'
#   Created wheel for pybullet: filename=pybullet-3.2.7-cp310-cp310-win_amd64.whl size=67429814 sha256=49390879a3c63bab172197ff29870621a5f4581712438618a031290c39a45882
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\4e\5f\56\9a32e9e7c862e85b0f01c90ba1e530e28f18aa990acbb89085
# Successfully built pybullet
# Installing collected packages: pybullet, panda-gym
#
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    ---------------------------------------- 0/2 [pybullet]
#    -------------------- ------------------- 1/2 [panda-gym]
#    ---------------------------------------- 2/2 [panda-gym]
#
# Successfully installed panda-gym-3.0.7 pybullet-3.2.7
#   DEPRECATION: Building 'pybullet' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pybullet'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import gymnasium as gym
import panda_gym

env = gym.make('PandaReach-v3', render_mode="human")

observation, info = env.reset()

for _ in range(1000):
    action = env.action_space.sample() # random action
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()
env.close()

# %%
### Manual control
env = gym.make("PandaReach-v3", render_mode="human")
observation, info = env.reset()

for _ in range(1000):
    current_position = observation["observation"][0:3]
    desired_position = observation["desired_goal"][0:3]
    action = 5.0 * (desired_position - current_position)
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()

# %%
env = gym.make(
    "PandaSlide-v3",
    render_mode="rgb_array",
    renderer="OpenGL",
    render_width=480,
    render_height=480,
    render_target_position=[0.2, 0, 0],
    render_distance=1.0,
    render_yaw=90,
    render_pitch=-70,
    render_roll=0,
)
env.reset()
image = env.render()  # RGB rendering of shape (480, 480, 3)
env.close()

# %%
import numpy as np
env = gym.make("PandaReachDense-v3", render_mode="rgb_array")
observation, _ = env.reset()

for _ in range(1000):
    state_id = env.save_state()

    # Sample 5 actions and choose the one that yields the best reward.
    best_reward = -np.inf
    best_action = None
    for _ in range(5):
        env.restore_state(state_id)
        action = env.action_space.sample()
        observation, reward, _, _, _ = env.step(action)
        if reward > best_reward:
            best_reward = reward
            best_action = action

    env.restore_state(state_id)
    env.remove_state(state_id)  # discard the state, as it is no longer needed

    # Step with the best action
    observation, reward, terminated, truncated, info = env.step(best_action)

    if terminated:
        observation, info = env.reset()

env.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 6
#       3 observation, _ = env.reset()
#       5 for _ in range(1000):
# ----> 6     state_id = env.save_state()
#       8     # Sample 5 actions and choose the one that yields the best reward.
#       9     best_reward = -np.inf
#
# AttributeError: 'TimeLimit' object has no attribute 'save_state'
